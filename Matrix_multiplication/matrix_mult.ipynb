# %%
import random
import time as t
l = 0
h= 10
cols = 10
rows= 10

choices = list (map(float, range(l,h)))
x = [random.choices (choices , k=cols) for _ in range(rows)]
y = [random.choices (choices , k=cols) for _ in range(rows)]

result = [([0]*cols) for i in range (rows)]

start = t.time()

for i in range(len(x)):
    for j in range(len(y[0])):
        for k in range(len(result)):
            result[i][j] += x[i][k] * y[k][j]
            
print(result)                                  
print("Time = ", t.time()-start)
# Out:
# [[235.0, 261.0, 272.0, 249.0, 184.0, 145.0, 250.0, 227.0, 184.0, 131.0], [274.0, 296.0, 403.0, 280.0, 204.0, 219.0, 334.0, 261.0, 171.0, 166.0], [140.0, 211.0, 277.0, 215.0, 195.0, 147.0, 200.0, 168.0, 136.0, 84.0], [240.0, 224.0, 299.0, 239.0, 143.0, 106.0, 257.0, 216.0, 121.0, 122.0], [198.0, 228.0, 314.0, 169.0, 157.0, 177.0, 224.0, 155.0, 140.0, 127.0], [157.0, 184.0, 191.0, 177.0, 117.0, 111.0, 179.0, 161.0, 113.0, 87.0], [250.0, 265.0, 318.0, 237.0, 149.0, 160.0, 282.0, 225.0, 152.0, 139.0], [207.0, 218.0, 268.0, 225.0, 147.0, 84.0, 227.0, 190.0, 127.0, 114.0], [190.0, 233.0, 267.0, 250.0, 186.0, 139.0, 254.0, 228.0, 153.0, 137.0], [206.0, 242.0, 375.0, 228.0, 169.0, 169.0, 251.0, 201.0, 121.0, 98.0]]
# Time =  0.0015912055969238281

# %%
import numpy as np
import time as t
x = np.random.rand(10,10)
y = np.random.rand(10,10)
start = t.time()
z = np.dot(x, y)

print(z)
print("Time = ",t.time()-start)
# Out:
# [[2.72390312 2.73956293 3.79120306 3.66343417 3.69421217 2.37695462
#   2.70750631 3.14636579 2.35958364 3.35031584]
#  [2.25011466 2.08102101 3.15981242 2.7216354  2.76847878 1.77900926
#   2.37126283 2.78933925 1.93100497 2.61211591]
#  [2.87566587 2.57690617 3.56948171 3.75686745 3.68841698 2.72552734
#   3.03948352 3.47403695 1.84597124 2.7858945 ]
#  [2.53670705 2.75066852 4.06107374 3.05278564 3.15089947 1.98718977
#   3.23151905 3.11213187 2.2660828  2.74429188]
#  [1.74011206 1.56603    2.35796332 2.38854395 2.2558695  1.70527157
#   1.80520076 2.0094818  1.58809219 1.96642188]
#  [3.33732368 2.77269109 3.95568609 3.21139616 2.93913962 2.54961535
#   3.22338644 3.62299249 2.81001238 3.64673201]
#  [3.22552089 2.72678969 3.76644143 3.28972934 3.04365218 2.79673584
#   2.81556049 3.45855531 2.58468481 3.47202329]
#  [2.53495536 2.59172021 4.11052362 3.66361583 3.23298321 2.86338386
#   2.84823499 4.12297253 2.97974977 3.60331088]
#  [2.75161082 2.53435218 3.43159159 3.19991927 2.54219426 2.42328417
#   2.35765645 3.60992473 2.4326369  3.13262776]
#  [2.12903347 2.14178285 3.11365361 3.14362029 3.1794602  1.82142084
#   2.29530561 3.31747531 2.27441893 3.1684043 ]]
# Time =  0.001316070556640625
